# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
effective_rivers = pd.read_csv("./good_rivers.csv")
effective_rivers
# Out:
#      segmentID  segmentInd                  Name  Unnamed: 3  Unnamed: 4  \
# 0            1        3758          Kansas River         NaN         NaN
# 1            1        3943          Kansas River         NaN         NaN
# 2            1        4137          Kansas River         NaN         NaN
# 3            1        4310          Kansas River         NaN         NaN
# 4            1        4501          Kansas River         NaN         NaN
# ..         ...         ...                   ...         ...         ...
# 768        167       16220  Missou at culbertson         NaN         NaN
# 769        167       16706  Missou at culbertson         NaN         NaN
# 770        167       17181  Missou at culbertson         NaN         NaN
# 771        167       17658  Missou at culbertson         NaN         NaN
# 772        167       18609  Missou at culbertson         NaN         NaN
#
#      Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# ...

# %%
cs_all = gpd.read_file("./intersected_validation.shp")
cs_all
# Out:
#      OBJECTID_1  FID_usBasi  oldReachID          area  reachID  FID_63_val  \
# 0             1           0        10.0  1.345455e+06     58.0          59
# 1             2           1        19.0  1.336048e+06     57.0          59
# 2             3          56        11.0  3.898778e+04      2.0          59
# 3             4           0        10.0  1.345455e+06     58.0          60
# 4             5           1        19.0  1.336048e+06     57.0          60
# ..          ...         ...         ...           ...      ...         ...
# 988         989          19       119.0  4.355455e+05     39.0          13
# 989         990          20       123.0  4.338981e+05     38.0          13
# 990         991          21       122.0  4.282865e+05     37.0          13
# 991         992          22       121.0  4.244440e+05     36.0          13
# 992         993          23       169.0  1.483447e+05     35.0          13
#
# ...
